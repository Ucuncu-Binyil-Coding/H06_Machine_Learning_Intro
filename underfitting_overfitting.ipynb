# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv("melb_data.csv")
df = df.dropna()

# %%
def get_mae(X,y,max_leaf_nodes=5):
    train_X, test_X, train_y, test_y = train_test_split(X,y,random_state=0)
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes,random_state=1)
    model.fit(train_X,train_y)
    predictions = model.predict(test_X)
    return mean_absolute_error(test_y,predictions)
    # return predictions

# %%
X = ["Rooms","Bathroom","Landsize","BuildingArea","YearBuilt","Lattitude","Longtitude"]
X = df[X]
y = df["Price"]

errors = []
for nodes in range(5,5000,5):
    # print(nodes)
    errors.append([nodes,get_mae(X,y,max_leaf_nodes=nodes)])

# %%
import matplotlib.pyplot as plt

xler = [x[0] for x in errors]
yler = [x[1] for x in errors]

xler[yler.index(min(yler))]

plt.plot(xler,yler)

# %%
get_mae(X,y,max_leaf_nodes=365)
# Out:
# 243610.53039895894
